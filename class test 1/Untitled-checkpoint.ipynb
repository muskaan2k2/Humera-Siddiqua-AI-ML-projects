# %%
n = int(input("How many transactions? "))
# Out:
# How many transactions? 9

# %%
data = []

# %%
for i in range(n):
    value = int(input("Enter transaction amount: "))
    transactions.append(value)
# Out:
# Enter transaction amount: 200
# Enter transaction amount: 500
# Enter transaction amount: 200
# Enter transaction amount: 100
# Enter transaction amount: 500
# Enter transaction amount: 200
# Enter transaction amount: 100
# Enter transaction amount: 500
# Enter transaction amount: 500

# %%
freq = {}

for t in transactions:
    if t in freq:
        freq[t] += 1
    else:
        freq[t] = 1

# %%
sorted_items = sorted(freq.items(), key=lambda x: (-x[1], x[0]))

# %%
result = [sorted_items[0][0], sorted_items[1][0]]
print(result)
# Out:
# [500, 200]

# %%
n = int(input("How many values? "))
# Out:
# How many values? 7

# %%
data = []

# %%
for i in range(n):
    value = input("Enter value (or None): ")
    if value == "None":
        data.append(None)
    else:
        data.append(int(value))
# Out:
# Enter value (or None): 10
# Enter value (or None): None
# Enter value (or None): 20
# Enter value (or None): 30
# Enter value (or None): None
# Enter value (or None): None
# Enter value (or None): 40

# %%
missing = 0

for item in data:
    if item is None:
        missing += 1

# %%
total = len(data)
percentage = (missing / n) * 100

# %%
print(round(percentage, 2))
# Out:
# 42.86
